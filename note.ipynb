# %%
import numpy as np
import json
import os
import cv2
import copy
import sklearn.metrics as metric
import pandas as pd

from tensorflow.keras import layers
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint 

import matplotlib.pyplot as plt
import matplotlib

# %%
EPOCHS = 50
INIT_LR = 1e-3
BS = 16
IMAGE_SIZE = (256, 256)
checkpoint_path = "models/training_1_40_binary_cp/cp.ckpt"
feature_path = "models/training_1_40_binary_feature.json"
model_path = "models/training_1.h5"
history_path = "models/training_1_40_binary_history.json"
magnification = "40X"
base_dataset = "images/binary_scenario"
class_dir = ['benign', 'malignant']

# %%
print("[INFO] indexing file images BreaKHis dataset...")
type_dataset = ['val', 'train']
dataset_train = []
dataset_val = []
for type_set in type_dataset:
    for class_item in class_dir:
        cur_dir = os.path.join(base_dataset, type_set, magnification ,class_item)
        for file in os.listdir(cur_dir):
            if type_set == 'train':
                dataset_train.append(os.path.join(cur_dir, file))
            else:
                dataset_val.append(os.path.join(cur_dir, file))

print("[INFO] load images BreaKHis dataset...")
#  load images
train_images = []
val_images = []
for type_set in type_dataset:
    cur_dataset = dataset_train if type_set == 'train' else dataset_val
    for image_path in cur_dataset:
        if ".png" in image_path:
            image = cv2.imread(image_path)
            image = cv2.resize(image, IMAGE_SIZE)
            if type_set == 'train':
                train_images.append(image)
            else:
                val_images.append(image)
# Out:
# [INFO] indexing file images BreaKHis dataset...
# [INFO] load images BreaKHis dataset...

# %%
# normalization
print("[INFO] normalization...")
train_x = np.array(train_images).astype("float32") / 255.0
val_x = np.array(val_images).astype("float32") / 255.0
# Out:
# [INFO] normalization...

# %%
class ConvAutoEncoder:
    """
    Core Convolutional AutoEncoder
    This class included with build method you can adjust of width height and depth of image
    default filters 128, and latent dimension 48
    """
    @staticmethod
    def build(width, height, depth, filters=(128,), latent_dim=48):
        input_shape = (height, width, depth)
        channel_dim = -1
        inputs = layers.Input(shape=input_shape)
        x = inputs
        # Encoder layer
        for f in filters:
            x = layers.Conv2D(f, (3, 3), strides=2, padding='same')(x)
            x = layers.LeakyReLU(alpha=0.2)(x)
            x = layers.BatchNormalization(axis=channel_dim, name='enc_filter_' + str(f))(x)
        volume_size = K.int_shape(x)
        x = layers.Flatten()(x)
        # Latent layer
        latent = layers.Dense(latent_dim, name="encoded")(x)
        # Decoder layer
        x = layers.Dense(np.prod(volume_size[1:]))(latent)
        x = layers.Reshape((volume_size[1], volume_size[2], volume_size[3]))(x)
        # Reverse on decoder
        for f in filters[::-1]:
            x = layers.Conv2DTranspose(f, (3, 3), strides=2, padding='same')(x)
            x = layers.LeakyReLU(alpha=0.2)(x)
            x = layers.BatchNormalization(axis=channel_dim, name='dec_filter_' + str(f))(x)
        x = layers.Conv2DTranspose(depth, (3, 3), padding="same")(x)
        outputs = layers.Activation("sigmoid", name="decoded")(x)
        auto_encoder = Model(inputs, outputs, name="auto_encoder")
        return auto_encoder

# %%
auto_encoder = load_model(model_path, compile=False)
# load our auto_encoder from disk
print("[INFO] loading auto encoder model...")
auto_encoder.load_weights(model_path)

# create the encoder model which consists of *just* the encoder
# portion of the auto encoder
encoder = Model(inputs=auto_encoder.input,
	outputs=auto_encoder.get_layer("encoded").output)

# quantify the contents of our input images using the encoder
print("[INFO] encoding images...")
features = encoder.predict(train_x)
# Out:
# c:\Users\lmher\Desktop\Informatica_4\PID\Trabajo\PID\venv\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# [INFO] loading auto encoder model...
# [INFO] encoding images...
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 261ms/step

# %%
indexes = list(range(0, train_x.shape[0]))
features_array = [[float(x) for x in y] for y in features]
labels = [path.split("\\")[3] for path in dataset_train]
data = {"indexes": indexes, "features": features_array, "locations": dataset_train, "labels":labels}

# %%
def euclidean(a, b):
	# compute and return the euclidean distance between two vectors
	return np.linalg.norm(a - b)

# %%
def perform_search(query_features, indexed_train, max_results=5):
	retrieved = []
	for idx in range(0, len(indexed_train["features"])):
		distance = euclidean(query_features, indexed_train["features"][idx])
		retrieved.append((distance, idx))
	retrieved = sorted(retrieved)[:max_results]
	return retrieved

# %%
print("[INFO] indexing file images BreaKHis dataset...")
# indexing file images
dataset = []
for class_item in class_dir:
    cur_dir = os.path.join(base_dataset, 'test', magnification, class_item)
    for file in os.listdir(cur_dir):
        dataset.append(os.path.join(cur_dir, file))

print("test len to retrieving:", len(dataset))
print("[INFO] load test images BreaKHis dataset...")
#  load images
images = []
for image_path in dataset:
    if ".png" in image_path:
        image = cv2.imread(image_path)
        image = cv2.resize(image, IMAGE_SIZE)
        images.append(image)
# Out:
# [INFO] indexing file images BreaKHis dataset...
# test len to retrieving: 199
# [INFO] load test images BreaKHis dataset...

# %%
# normalization
print("[INFO] normalization...")
test_x = np.array(images).astype("float32") / 255.0
# Out:
# [INFO] normalization...

# %%
from collections import Counter

def most_common(arr):
    print(arr)
    print("-"*100)
    return Counter(arr).most_common(1)[0][0]

# %%
with open(feature_path) as f:
  training_indexed = json.load(f)

query_indexes = list(range(0, test_x.shape[0]))
label_builder = list(np.unique(training_indexed["labels"]))
class_builder = {label_unique:[] for label_unique in label_builder}
recalls = copy.deepcopy(class_builder)
precisions = copy.deepcopy(class_builder)
# loop over the testing indexes
for i in query_indexes:
    queryFeatures = features[i]
    results = perform_search(queryFeatures, training_indexed, max_results=5)
    # Las etiquetas de los más cercanos
    labels_ret = [training_indexed["labels"][r[1]] for r in results]
    print(most_common(labels_ret))
    # label_true = dataset[i].split("\\")[3]
    # label_trues = [label_true for _ in labels_ret]
    # recall = metric.recall_score(label_trues, labels_ret, average='weighted')
    # precision = metric.precision_score(label_trues, labels_ret, average='weighted')
    # recalls[label_true].append(recall)
    # precisions[label_true].append(precision)
# Out:
# [(np.float64(3517.63174203032), 986), (np.float64(3517.63174203032), 1093), (np.float64(3535.358604168788), 1309), (np.float64(3568.9960607042667), 957), (np.float64(3591.713578598242), 1254)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3651.8569780147836), 986), (np.float64(3651.8569780147836), 1093), (np.float64(3729.838885484723), 957), (np.float64(3772.806048286515), 1262), (np.float64(3789.216120594741), 67)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'benign']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3750.555374780561), 986), (np.float64(3750.555374780561), 1093), (np.float64(3868.9364606983463), 957), (np.float64(3886.89031951345), 1309), (np.float64(3903.3405300853447), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3535.0143262951165), 986), (np.float64(3535.0143262951165), 1093), (np.float64(3606.8465793875425), 1309), (np.float64(3610.148451356029), 957), (np.float64(3632.8255888111903), 1154)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3704.002244661045), 986), (np.float64(3704.002244661045), 1093), (np.float64(3889.1632803335015), 1262), (np.float64(3891.6627853577957), 991), (np.float64(3891.6627853577957), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3313.767842452894), 986), (np.float64(3313.767842452894), 1093), (np.float64(3430.5043341208275), 991), (np.float64(3430.5043341208275), 1095), (np.float64(3463.3214672130534), 1309)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2890.1065733884825), 986), (np.float64(2890.1065733884825), 1093), (np.float64(2909.61362733175), 991), (np.float64(2909.61362733175), 1095), (np.float64(2927.1026597767623), 990)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3196.353693222136), 986), (np.float64(3196.353693222136), 1093), (np.float64(3257.424184959184), 1309), (np.float64(3265.328525193608), 1254), (np.float64(3288.4847934089385), 957)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3322.4560249915858), 986), (np.float64(3322.4560249915858), 1093), (np.float64(3420.277420215086), 1309), (np.float64(3428.025544615852), 957), (np.float64(3452.8576053757433), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3506.813213743405), 986), (np.float64(3506.813213743405), 1093), (np.float64(3521.5367581456226), 1071), (np.float64(3594.9624368108657), 1262), (np.float64(3607.831968463424), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3481.864633478651), 831), (np.float64(3513.264845905822), 986), (np.float64(3513.264845905822), 1093), (np.float64(3602.8254982660774), 1262), (np.float64(3616.723207459829), 1168)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3330.6759122940507), 986), (np.float64(3330.6759122940507), 1093), (np.float64(3404.7725196954048), 991), (np.float64(3404.7725196954048), 1095), (np.float64(3466.740189549617), 1309)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3141.885837177807), 986), (np.float64(3141.885837177807), 1093), (np.float64(3275.3241076606832), 1262), (np.float64(3313.872617309647), 1071), (np.float64(3321.4918272005307), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3092.1040295361554), 986), (np.float64(3092.1040295361554), 1093), (np.float64(3208.5516270293892), 991), (np.float64(3208.5516270293892), 1095), (np.float64(3221.4802545344883), 1154)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3356.663912972332), 986), (np.float64(3356.663912972332), 1093), (np.float64(3444.9956492959104), 1309), (np.float64(3472.007748495872), 67), (np.float64(3481.0607944709127), 998)]
# ['malignant', 'malignant', 'malignant', 'benign', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3043.931264695556), 1262), (np.float64(3092.5711778581917), 1254), (np.float64(3178.4481082527786), 1071), (np.float64(3194.7125633192604), 1124), (np.float64(3197.9856014422776), 65)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'benign']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3891.840498492261), 986), (np.float64(3891.840498492261), 1093), (np.float64(3931.8063258014986), 1263), (np.float64(3967.607362802544), 992), (np.float64(3967.607362802544), 1097)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3287.6604030768244), 986), (np.float64(3287.6604030768244), 1093), (np.float64(3436.28157793775), 991), (np.float64(3436.28157793775), 1095), (np.float64(3443.0668709495762), 1154)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3333.4043937967613), 1263), (np.float64(3358.5380205798774), 1020), (np.float64(3366.926712702485), 1261), (np.float64(3377.272653990546), 808), (np.float64(3381.239825247656), 1171)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3180.05210195209), 1188), (np.float64(3312.9319624622003), 986), (np.float64(3312.9319624622003), 1093), (np.float64(3362.953893321471), 1114), (np.float64(3370.4605204315344), 67)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'benign']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3629.927968808165), 1168), (np.float64(3667.811579537956), 986), (np.float64(3667.811579537956), 1093), (np.float64(3701.271628232367), 957), (np.float64(3709.6807404531514), 990)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3031.569915096974), 986), (np.float64(3031.569915096974), 1093), (np.float64(3098.749616881728), 991), (np.float64(3098.749616881728), 1095), (np.float64(3123.79628358842), 990)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3028.740858793226), 986), (np.float64(3028.740858793226), 1093), (np.float64(3049.2009226522428), 991), (np.float64(3049.2009226522428), 1095), (np.float64(3105.22432478821), 992)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3348.389501891409), 986), (np.float64(3348.389501891409), 1093), (np.float64(3452.078207165509), 957), (np.float64(3482.6273411171105), 991), (np.float64(3482.6273411171105), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3619.46383356581), 986), (np.float64(3619.46383356581), 1093), (np.float64(3656.41842207674), 1014), (np.float64(3664.4781672711983), 1309), (np.float64(3666.720405375213), 67)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'benign']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3816.196925404833), 986), (np.float64(3816.196925404833), 1093), (np.float64(3847.380712853266), 991), (np.float64(3847.380712853266), 1095), (np.float64(3880.7445207057835), 990)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4156.54755472032), 986), (np.float64(4156.54755472032), 1093), (np.float64(4264.918101457725), 1254), (np.float64(4277.84243862548), 991), (np.float64(4277.84243862548), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3306.9625749410925), 957), (np.float64(3342.4856507657605), 986), (np.float64(3342.4856507657605), 1093), (np.float64(3349.2017835469783), 1262), (np.float64(3353.5115386760167), 67)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'benign']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3457.68139710901), 67), (np.float64(3534.8776621318652), 986), (np.float64(3534.8776621318652), 1093), (np.float64(3591.3403119314626), 1309), (np.float64(3608.8395230253363), 957)]
# ['benign', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3623.47371381795), 986), (np.float64(3623.47371381795), 1093), (np.float64(3655.466305868185), 1071), (np.float64(3672.7056459984165), 67), (np.float64(3674.7082576487137), 1262)]
# ['malignant', 'malignant', 'malignant', 'benign', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3547.194997376733), 1309), (np.float64(3663.4096582531633), 957), (np.float64(3705.7398800615247), 991), (np.float64(3705.7398800615247), 1095), (np.float64(3726.912661281928), 1014)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3535.2577707905684), 986), (np.float64(3535.2577707905684), 1093), (np.float64(3574.8701465728413), 1309), (np.float64(3587.5805318953658), 957), (np.float64(3621.6617675821917), 67)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'benign']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3263.078404892046), 986), (np.float64(3263.078404892046), 1093), (np.float64(3357.2024113158473), 67), (np.float64(3439.3061254214936), 957), (np.float64(3443.4423541925835), 1309)]
# ['malignant', 'malignant', 'benign', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3184.9435056826906), 986), (np.float64(3184.9435056826906), 1093), (np.float64(3323.765009879204), 991), (np.float64(3323.765009879204), 1095), (np.float64(3332.258317739148), 1309)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3307.27437309683), 986), (np.float64(3307.27437309683), 1093), (np.float64(3377.017043183399), 991), (np.float64(3377.017043183399), 1095), (np.float64(3419.3025026976184), 990)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3738.498400218697), 1309), (np.float64(3746.273924040635), 957), (np.float64(3758.575799075975), 986), (np.float64(3758.575799075975), 1093), (np.float64(3867.507929539624), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3774.9052408252523), 986), (np.float64(3774.9052408252523), 1093), (np.float64(3813.078438260569), 998), (np.float64(3845.0051125692894), 1262), (np.float64(3876.785732346389), 1071)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3475.264743050154), 986), (np.float64(3475.264743050154), 1093), (np.float64(3576.9288055265724), 991), (np.float64(3576.9288055265724), 1095), (np.float64(3638.6734295229785), 990)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3474.8508067502635), 986), (np.float64(3474.8508067502635), 1093), (np.float64(3487.628686331182), 957), (np.float64(3567.789166923459), 1309), (np.float64(3586.2508123647335), 67)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'benign']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3494.5360288795996), 986), (np.float64(3494.5360288795996), 1093), (np.float64(3580.9957342385524), 957), (np.float64(3603.671860098694), 67), (np.float64(3622.806504905293), 991)]
# ['malignant', 'malignant', 'malignant', 'benign', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3257.9997556833937), 986), (np.float64(3257.9997556833937), 1093), (np.float64(3363.6995961922166), 957), (np.float64(3382.3506602994303), 991), (np.float64(3382.3506602994303), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3711.3249561079347), 986), (np.float64(3711.3249561079347), 1093), (np.float64(3883.185572728237), 1154), (np.float64(3897.492992624995), 67), (np.float64(3903.5949515251486), 998)]
# ['malignant', 'malignant', 'malignant', 'benign', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3572.957752411792), 986), (np.float64(3572.957752411792), 1093), (np.float64(3659.7838234569845), 1188), (np.float64(3681.373330755427), 67), (np.float64(3704.2081078360775), 1262)]
# ['malignant', 'malignant', 'malignant', 'benign', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3095.079645991515), 986), (np.float64(3095.079645991515), 1093), (np.float64(3134.8566091117727), 1154), (np.float64(3170.7426782070434), 1164), (np.float64(3229.348545867697), 1168)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3276.6821419107323), 957), (np.float64(3326.972678210609), 986), (np.float64(3326.972678210609), 1093), (np.float64(3370.210736886165), 1309), (np.float64(3384.018490930948), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3451.6516174144513), 986), (np.float64(3451.6516174144513), 1093), (np.float64(3472.4587693803815), 990), (np.float64(3472.4587693803815), 1096), (np.float64(3510.5433430777175), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4038.498378726303), 992), (np.float64(4038.498378726303), 1097), (np.float64(4062.2028582573084), 989), (np.float64(4066.302339097904), 986), (np.float64(4066.302339097904), 1093)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3631.766566785628), 986), (np.float64(3631.766566785628), 1093), (np.float64(3804.1627651682365), 831), (np.float64(3806.9989942558745), 1254), (np.float64(3825.3049385891386), 808)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3248.4685248732476), 986), (np.float64(3248.4685248732476), 1093), (np.float64(3353.045282907524), 1262), (np.float64(3441.003673142513), 1263), (np.float64(3447.039570902555), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3614.114706140484), 986), (np.float64(3614.114706140484), 1093), (np.float64(3700.7655813910046), 332), (np.float64(3716.8179990008234), 998), (np.float64(3790.705059396906), 991)]
# ['malignant', 'malignant', 'benign', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3213.737971647001), 986), (np.float64(3213.737971647001), 1093), (np.float64(3267.2116834844696), 1262), (np.float64(3289.933482925348), 67), (np.float64(3319.8599977582444), 831)]
# ['malignant', 'malignant', 'malignant', 'benign', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3806.77412127016), 986), (np.float64(3806.77412127016), 1093), (np.float64(3903.173578542753), 991), (np.float64(3903.173578542753), 1095), (np.float64(3924.6052286625527), 998)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3002.911815495492), 986), (np.float64(3002.911815495492), 1093), (np.float64(3084.595519116999), 998), (np.float64(3112.7832970723816), 991), (np.float64(3112.7832970723816), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2686.6661375868434), 986), (np.float64(2686.6661375868434), 1093), (np.float64(2856.4237544892885), 991), (np.float64(2856.4237544892885), 1095), (np.float64(2876.540746013172), 957)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2853.9545400999536), 986), (np.float64(2853.9545400999536), 1093), (np.float64(3031.2108786959157), 991), (np.float64(3031.2108786959157), 1095), (np.float64(3051.057430493368), 990)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2947.01113722778), 986), (np.float64(2947.01113722778), 1093), (np.float64(3013.722349343313), 991), (np.float64(3013.722349343313), 1095), (np.float64(3110.1493519165483), 998)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3146.8634731201855), 986), (np.float64(3146.8634731201855), 1093), (np.float64(3203.0228828080953), 1154), (np.float64(3287.780772640178), 991), (np.float64(3287.780772640178), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2813.0608250161117), 986), (np.float64(2813.0608250161117), 1093), (np.float64(3029.473892539911), 1154), (np.float64(3052.866050708537), 991), (np.float64(3052.866050708537), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3313.295518544624), 986), (np.float64(3313.295518544624), 1093), (np.float64(3324.1534629565), 1154), (np.float64(3524.190644793181), 1561), (np.float64(3537.9848436270827), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3592.3480698266735), 986), (np.float64(3592.3480698266735), 1093), (np.float64(3684.3407438301806), 957), (np.float64(3700.894213602035), 1154), (np.float64(3712.348028056255), 831)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3784.3832107807943), 957), (np.float64(3813.522353154648), 986), (np.float64(3813.522353154648), 1093), (np.float64(3815.336867268292), 831), (np.float64(3864.417673360656), 1262)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3307.4204760849807), 1071), (np.float64(3416.978619321985), 1309), (np.float64(3433.522680836747), 1262), (np.float64(3435.0707225723922), 986), (np.float64(3435.0707225723922), 1093)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2445.6608815182076), 986), (np.float64(2445.6608815182076), 1093), (np.float64(2620.6853270851343), 991), (np.float64(2620.6853270851343), 1095), (np.float64(2672.2563417171705), 990)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3533.4248693457575), 986), (np.float64(3533.4248693457575), 1093), (np.float64(3607.6360367911802), 998), (np.float64(3637.7743996869685), 374), (np.float64(3682.076983944673), 1571)]
# ['malignant', 'malignant', 'malignant', 'benign', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3794.5594072202416), 986), (np.float64(3794.5594072202416), 1093), (np.float64(3803.3545949523013), 1571), (np.float64(3812.6543271261944), 1188), (np.float64(3912.4911121097252), 368)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'benign']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2868.5617928188303), 986), (np.float64(2868.5617928188303), 1093), (np.float64(3048.0181280442184), 991), (np.float64(3048.0181280442184), 1095), (np.float64(3050.404926331046), 998)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2777.515346506224), 986), (np.float64(2777.515346506224), 1093), (np.float64(2912.198425178452), 991), (np.float64(2912.198425178452), 1095), (np.float64(2932.0123254233517), 998)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3489.5485067581635), 986), (np.float64(3489.5485067581635), 1093), (np.float64(3600.691821342517), 998), (np.float64(3615.523719952062), 1551), (np.float64(3695.487762961443), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3000.8991738900177), 986), (np.float64(3000.8991738900177), 1093), (np.float64(3055.2793570430435), 991), (np.float64(3055.2793570430435), 1095), (np.float64(3159.9173247539475), 990)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3209.847476918101), 986), (np.float64(3209.847476918101), 1093), (np.float64(3319.409484407731), 991), (np.float64(3319.409484407731), 1095), (np.float64(3374.342749678106), 998)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3388.119840854228), 986), (np.float64(3388.119840854228), 1093), (np.float64(3468.272512746039), 991), (np.float64(3468.272512746039), 1095), (np.float64(3507.2933796170933), 990)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3877.586550829872), 986), (np.float64(3877.586550829872), 1093), (np.float64(3981.331956969108), 1154), (np.float64(4006.808884565726), 957), (np.float64(4009.1957519756443), 1309)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3382.9921744471403), 986), (np.float64(3382.9921744471403), 1093), (np.float64(3445.9179452833037), 1154), (np.float64(3558.4625405758093), 1168), (np.float64(3571.4633858010616), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3461.149543817103), 986), (np.float64(3461.149543817103), 1093), (np.float64(3548.400742145681), 1154), (np.float64(3619.8183958936975), 991), (np.float64(3619.8183958936975), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3058.602124573051), 986), (np.float64(3058.602124573051), 1093), (np.float64(3076.118065952115), 991), (np.float64(3076.118065952115), 1095), (np.float64(3104.7070367064416), 990)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3467.3571429404824), 371), (np.float64(3468.160311984068), 332), (np.float64(3469.4531891030488), 998), (np.float64(3486.420397414741), 1262), (np.float64(3525.9385672538106), 65)]
# ['benign', 'benign', 'malignant', 'malignant', 'benign']
# ----------------------------------------------------------------------------------------------------
# benign
# [(np.float64(3009.9790007536462), 986), (np.float64(3009.9790007536462), 1093), (np.float64(3048.3978891244783), 991), (np.float64(3048.3978891244783), 1095), (np.float64(3053.8572687201145), 1071)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3115.7116252303067), 1262), (np.float64(3240.936991435723), 831), (np.float64(3298.5277703179136), 1263), (np.float64(3303.5394355797275), 1020), (np.float64(3308.7948387877555), 808)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3014.3507736049937), 808), (np.float64(3044.1720989425794), 831), (np.float64(3100.4798677802637), 67), (np.float64(3110.594588763107), 1262), (np.float64(3171.9593247262587), 1154)]
# ['malignant', 'malignant', 'benign', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3191.201100163988), 1254), (np.float64(3235.766737762162), 986), (np.float64(3235.766737762162), 1093), (np.float64(3301.1248563737795), 998), (np.float64(3305.987743411791), 1261)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3079.560183512969), 1254), (np.float64(3084.87791337837), 986), (np.float64(3084.87791337837), 1093), (np.float64(3130.0623037991586), 991), (np.float64(3130.0623037991586), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2538.0011132511463), 986), (np.float64(2538.0011132511463), 1093), (np.float64(2728.898891146424), 998), (np.float64(2737.381363281144), 991), (np.float64(2737.381363281144), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2572.3878798832948), 986), (np.float64(2572.3878798832948), 1093), (np.float64(2679.084372057684), 998), (np.float64(2764.5222818078096), 991), (np.float64(2764.5222818078096), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3916.156786792754), 1262), (np.float64(3927.9607658767654), 1263), (np.float64(3948.53866169328), 986), (np.float64(3948.53866169328), 1093), (np.float64(3958.4446708591277), 831)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3457.980682460046), 986), (np.float64(3457.980682460046), 1093), (np.float64(3487.366595458514), 957), (np.float64(3503.374604661043), 831), (np.float64(3548.0591908913157), 1168)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2917.9105579636125), 986), (np.float64(2917.9105579636125), 1093), (np.float64(3090.994556005866), 998), (np.float64(3102.419838367541), 991), (np.float64(3102.419838367541), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4250.5456298587615), 986), (np.float64(4250.5456298587615), 1093), (np.float64(4296.543440351653), 1254), (np.float64(4378.186347591672), 998), (np.float64(4385.420800610775), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3868.0753695179046), 986), (np.float64(3868.0753695179046), 1093), (np.float64(3943.806767733928), 1309), (np.float64(3967.409245301871), 991), (np.float64(3967.409245301871), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4791.835789814589), 1263), (np.float64(4821.9341231084745), 1254), (np.float64(4858.301675805269), 986), (np.float64(4858.301675805269), 1093), (np.float64(4893.010201778895), 1261)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4328.99381648829), 986), (np.float64(4328.99381648829), 1093), (np.float64(4445.769181880944), 998), (np.float64(4468.3760068891215), 1254), (np.float64(4475.2593619177305), 1263)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4682.568072546251), 986), (np.float64(4682.568072546251), 1093), (np.float64(4745.105362197134), 1309), (np.float64(4776.023867184894), 998), (np.float64(4782.912050058438), 1071)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4392.720800153951), 986), (np.float64(4392.720800153951), 1093), (np.float64(4547.852563311603), 991), (np.float64(4547.852563311603), 1095), (np.float64(4548.733124147317), 998)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4749.2720126594495), 986), (np.float64(4749.2720126594495), 1093), (np.float64(4863.724543849975), 1309), (np.float64(4868.701153800292), 991), (np.float64(4868.701153800292), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3983.7386737598017), 986), (np.float64(3983.7386737598017), 1093), (np.float64(4036.632382094202), 1309), (np.float64(4059.0565647267754), 991), (np.float64(4059.0565647267754), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4489.576411973821), 986), (np.float64(4489.576411973821), 1093), (np.float64(4654.339990890891), 1071), (np.float64(4663.000642828767), 1309), (np.float64(4663.158684268293), 1254)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3947.944027112511), 986), (np.float64(3947.944027112511), 1093), (np.float64(3971.4814124566374), 957), (np.float64(4011.932623992379), 990), (np.float64(4011.932623992379), 1096)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4128.845305114422), 986), (np.float64(4128.845305114422), 1093), (np.float64(4185.304998242317), 1309), (np.float64(4188.644348294476), 991), (np.float64(4188.644348294476), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3956.177199802692), 986), (np.float64(3956.177199802692), 1093), (np.float64(4085.459884171723), 991), (np.float64(4085.459884171723), 1095), (np.float64(4107.118928229489), 1263)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4495.780479695373), 1014), (np.float64(4512.723182349112), 1071), (np.float64(4514.596667009486), 986), (np.float64(4514.596667009486), 1093), (np.float64(4533.820550056849), 1171)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4290.189837804893), 1154), (np.float64(4446.750338336499), 986), (np.float64(4446.750338336499), 1093), (np.float64(4480.928466793897), 988), (np.float64(4480.928466793897), 1094)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4088.5166611045843), 986), (np.float64(4088.5166611045843), 1093), (np.float64(4245.437752062187), 1262), (np.float64(4266.1501123489425), 1154), (np.float64(4280.093588581062), 998)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4420.737548372934), 1071), (np.float64(4430.369746018486), 986), (np.float64(4430.369746018486), 1093), (np.float64(4475.724371394975), 998), (np.float64(4524.382842959151), 1262)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3858.1396555801502), 986), (np.float64(3858.1396555801502), 1093), (np.float64(4067.2219767187894), 991), (np.float64(4067.2219767187894), 1095), (np.float64(4097.189276768016), 1154)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4769.577272685896), 986), (np.float64(4769.577272685896), 1093), (np.float64(4802.39620729723), 1263), (np.float64(4872.50340657856), 1261), (np.float64(4896.1065944356915), 998)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4787.0668522592105), 986), (np.float64(4787.0668522592105), 1093), (np.float64(4874.287509031035), 998), (np.float64(4892.99381135079), 1263), (np.float64(4963.177835348084), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3812.9453965862654), 986), (np.float64(3812.9453965862654), 1093), (np.float64(3992.5515351974614), 991), (np.float64(3992.5515351974614), 1095), (np.float64(4018.626762574069), 1309)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3982.8751471951196), 986), (np.float64(3982.8751471951196), 1093), (np.float64(4068.8107470758832), 998), (np.float64(4120.362582388724), 991), (np.float64(4120.362582388724), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3456.954459155062), 986), (np.float64(3456.954459155062), 1093), (np.float64(3555.0479955712212), 1154), (np.float64(3681.331265280718), 831), (np.float64(3716.9181894540347), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3871.7010822311863), 831), (np.float64(3878.6753537695104), 1154), (np.float64(4026.985586716165), 986), (np.float64(4026.985586716165), 1093), (np.float64(4043.617900449268), 808)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4276.970369301028), 986), (np.float64(4276.970369301028), 1093), (np.float64(4318.383942032698), 1309), (np.float64(4342.899415835062), 1254), (np.float64(4350.765248577174), 1025)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3835.8965317520624), 986), (np.float64(3835.8965317520624), 1093), (np.float64(3916.8421071331227), 831), (np.float64(3933.2030079056376), 991), (np.float64(3933.2030079056376), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4480.128964026137), 986), (np.float64(4480.128964026137), 1093), (np.float64(4509.870942494419), 1561), (np.float64(4513.768406030952), 1154), (np.float64(4564.584417985263), 1560)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4311.232036210953), 986), (np.float64(4311.232036210953), 1093), (np.float64(4455.1031683172405), 1571), (np.float64(4463.98640927723), 998), (np.float64(4468.658324998289), 1560)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4294.719474104477), 986), (np.float64(4294.719474104477), 1093), (np.float64(4372.697871915041), 1571), (np.float64(4436.519323008588), 998), (np.float64(4445.1382680569495), 1309)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4410.155146300842), 1154), (np.float64(4464.158376005556), 986), (np.float64(4464.158376005556), 1093), (np.float64(4481.962550828243), 1561), (np.float64(4633.266667377608), 1560)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4182.556327016715), 986), (np.float64(4182.556327016715), 1093), (np.float64(4223.292206471287), 991), (np.float64(4223.292206471287), 1095), (np.float64(4242.567639970343), 1168)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4152.39361375653), 1154), (np.float64(4234.996122592776), 986), (np.float64(4234.996122592776), 1093), (np.float64(4361.268410818284), 991), (np.float64(4361.268410818284), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3802.2064635042534), 986), (np.float64(3802.2064635042534), 1093), (np.float64(3861.9230732475917), 1154), (np.float64(3910.5178119069915), 1168), (np.float64(3945.184828025543), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3907.664636646984), 986), (np.float64(3907.664636646984), 1093), (np.float64(4015.8567203438456), 831), (np.float64(4076.2181806007047), 991), (np.float64(4076.2181806007047), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4476.996254002984), 831), (np.float64(4491.037109407429), 1262), (np.float64(4511.920806827825), 1560), (np.float64(4551.104129554458), 986), (np.float64(4551.104129554458), 1093)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4362.300882564789), 986), (np.float64(4362.300882564789), 1093), (np.float64(4388.536234886424), 831), (np.float64(4406.02601527897), 44), (np.float64(4444.4588131754845), 957)]
# ['malignant', 'malignant', 'malignant', 'benign', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4109.6799151210225), 986), (np.float64(4109.6799151210225), 1093), (np.float64(4156.264814433212), 1262), (np.float64(4165.511176755886), 831), (np.float64(4265.162244296094), 1571)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4019.5504393387837), 986), (np.float64(4019.5504393387837), 1093), (np.float64(4070.3006228546433), 1154), (np.float64(4156.512020270938), 1561), (np.float64(4244.612777055285), 1571)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3346.5683879040216), 986), (np.float64(3346.5683879040216), 1093), (np.float64(3532.6645153234685), 998), (np.float64(3554.8757048774896), 1262), (np.float64(3566.810845807384), 1571)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3809.4570149720576), 986), (np.float64(3809.4570149720576), 1093), (np.float64(3974.0379801639588), 998), (np.float64(3998.366037923807), 1262), (np.float64(4025.2901573831778), 831)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3382.553267653918), 986), (np.float64(3382.553267653918), 1093), (np.float64(3434.2742208636855), 1262), (np.float64(3470.8687169530003), 1154), (np.float64(3472.6744216034704), 808)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3785.0517142063286), 831), (np.float64(3906.581221734971), 808), (np.float64(4011.1619474944514), 986), (np.float64(4011.1619474944514), 1093), (np.float64(4018.448408303414), 1560)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3599.5028484439595), 986), (np.float64(3599.5028484439595), 1093), (np.float64(3695.384277991085), 1154), (np.float64(3698.3026254192987), 991), (np.float64(3698.3026254192987), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3509.433583738871), 986), (np.float64(3509.433583738871), 1093), (np.float64(3509.5740052089013), 1154), (np.float64(3561.2051067953184), 957), (np.float64(3602.0775670626026), 1309)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# ...
# malignant
# [(np.float64(3573.572422625904), 986), (np.float64(3573.572422625904), 1093), (np.float64(3634.119957534813), 1154), (np.float64(3687.7169372051494), 957), (np.float64(3716.2315625335455), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3473.073052549637), 957), (np.float64(3520.2465960963245), 1168), (np.float64(3539.045734338713), 1154), (np.float64(3573.558985817539), 986), (np.float64(3573.558985817539), 1093)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3519.6537272188025), 1154), (np.float64(3528.720110242154), 1164), (np.float64(3581.242947241162), 986), (np.float64(3581.242947241162), 1093), (np.float64(3635.816269319248), 1168)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3418.6376225828308), 986), (np.float64(3418.6376225828308), 1093), (np.float64(3467.300254902207), 1154), (np.float64(3521.781285068118), 957), (np.float64(3529.6706167889542), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3453.4740622941786), 957), (np.float64(3470.618743214506), 986), (np.float64(3470.618743214506), 1093), (np.float64(3512.4643640688173), 1154), (np.float64(3541.9572493567066), 1168)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3735.4870804157176), 1154), (np.float64(3765.3799297567307), 1164), (np.float64(3767.644754418122), 986), (np.float64(3767.644754418122), 1093), (np.float64(3775.675055747795), 67)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'benign']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3572.6590668960102), 986), (np.float64(3572.6590668960102), 1093), (np.float64(3605.107807700228), 991), (np.float64(3605.107807700228), 1095), (np.float64(3605.826432835712), 990)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3452.559382277714), 1154), (np.float64(3515.9278404828337), 957), (np.float64(3543.6593844622003), 986), (np.float64(3543.6593844622003), 1093), (np.float64(3575.2701396534417), 1168)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3366.63433459557), 986), (np.float64(3366.63433459557), 1093), (np.float64(3434.660662075432), 991), (np.float64(3434.660662075432), 1095), (np.float64(3437.5436681292963), 1154)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3608.813110165122), 986), (np.float64(3608.813110165122), 1093), (np.float64(3691.3142612560114), 957), (np.float64(3733.882049538468), 1154), (np.float64(3766.310347176514), 67)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'benign']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3607.702103408253), 986), (np.float64(3607.702103408253), 1093), (np.float64(3621.862939945816), 991), (np.float64(3621.862939945816), 1095), (np.float64(3663.481545868855), 992)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3551.035520224672), 986), (np.float64(3551.035520224672), 1093), (np.float64(3633.6102142026475), 1154), (np.float64(3645.447479143336), 991), (np.float64(3645.447479143336), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3525.4780517305217), 1154), (np.float64(3553.8541063565845), 986), (np.float64(3553.8541063565845), 1093), (np.float64(3616.277036218316), 957), (np.float64(3633.5395585914594), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3273.971508400368), 986), (np.float64(3273.971508400368), 1093), (np.float64(3409.8491383958426), 1154), (np.float64(3426.5821224446813), 991), (np.float64(3426.5821224446813), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3609.6920813705456), 957), (np.float64(3610.037646272717), 986), (np.float64(3610.037646272717), 1093), (np.float64(3668.7839289804733), 991), (np.float64(3668.7839289804733), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3388.651454835477), 957), (np.float64(3395.408823068494), 986), (np.float64(3395.408823068494), 1093), (np.float64(3424.571049781601), 1309), (np.float64(3446.6172977092574), 991)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3678.548828756858), 1154), (np.float64(3792.1891020922035), 986), (np.float64(3792.1891020922035), 1093), (np.float64(3799.564081121148), 1168), (np.float64(3799.6716949197366), 990)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3471.8840799348136), 986), (np.float64(3471.8840799348136), 1093), (np.float64(3518.1761764151192), 991), (np.float64(3518.1761764151192), 1095), (np.float64(3532.759482478347), 957)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3547.0696798395447), 1154), (np.float64(3659.3310505496456), 986), (np.float64(3659.3310505496456), 1093), (np.float64(3743.416506082565), 957), (np.float64(3760.4372545742212), 990)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3464.718991096229), 986), (np.float64(3464.718991096229), 1093), (np.float64(3531.1525019281644), 991), (np.float64(3531.1525019281644), 1095), (np.float64(3533.192526275922), 990)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(4045.6218461102617), 986), (np.float64(4045.6218461102617), 1093), (np.float64(4099.941672352077), 990), (np.float64(4099.941672352077), 1096), (np.float64(4102.92637035713), 1154)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3083.1564603548013), 67), (np.float64(3134.6280542613727), 983), (np.float64(3149.802036821899), 986), (np.float64(3149.802036821899), 1093), (np.float64(3156.7476919993715), 991)]
# ['benign', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3169.4386672157675), 1262), (np.float64(3199.2888989472444), 67), (np.float64(3231.1778510474583), 986), (np.float64(3231.1778510474583), 1093), (np.float64(3244.3879445204307), 957)]
# ['malignant', 'benign', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3494.227885667075), 332), (np.float64(3546.319434610685), 986), (np.float64(3546.319434610685), 1093), (np.float64(3557.1992765082437), 1254), (np.float64(3561.0327342969517), 922)]
# ['benign', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3270.1203441594616), 67), (np.float64(3360.2211795215453), 986), (np.float64(3360.2211795215453), 1093), (np.float64(3392.4110505251138), 983), (np.float64(3413.0843876587237), 1227)]
# ['benign', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3076.260977389253), 986), (np.float64(3076.260977389253), 1093), (np.float64(3101.9584752921405), 1263), (np.float64(3113.7464344534246), 991), (np.float64(3113.7464344534246), 1095)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2889.5365614121097), 67), (np.float64(2921.621665975477), 957), (np.float64(2950.66224340377), 1309), (np.float64(2973.8958174889503), 991), (np.float64(2973.8958174889503), 1095)]
# ['benign', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2643.684906341548), 67), (np.float64(2694.2117127519946), 957), (np.float64(2732.691825731849), 922), (np.float64(2788.8930184366905), 991), (np.float64(2788.8930184366905), 1095)]
# ['benign', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2795.657180918916), 67), (np.float64(2845.423612765913), 957), (np.float64(2878.975029802535), 991), (np.float64(2878.975029802535), 1095), (np.float64(2886.671810903809), 922)]
# ['benign', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3044.861817617289), 67), (np.float64(3076.795203992681), 957), (np.float64(3103.8835741343273), 986), (np.float64(3103.8835741343273), 1093), (np.float64(3158.994337511461), 1309)]
# ['benign', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2580.196714416087), 67), (np.float64(2650.9957285061273), 986), (np.float64(2650.9957285061273), 1093), (np.float64(2654.8523380180827), 991), (np.float64(2654.8523380180827), 1095)]
# ['benign', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3351.3484553649673), 922), (np.float64(3363.303008227571), 67), (np.float64(3375.1467680660267), 991), (np.float64(3375.1467680660267), 1095), (np.float64(3376.515841819108), 75)]
# ['malignant', 'benign', 'malignant', 'malignant', 'benign']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2921.591297954522), 986), (np.float64(2921.591297954522), 1093), (np.float64(2946.0299453158073), 67), (np.float64(2955.551126101519), 957), (np.float64(2956.432453424087), 991)]
# ['malignant', 'malignant', 'benign', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3152.6337411352106), 922), (np.float64(3203.796445419727), 1020), (np.float64(3228.5342614840115), 1309), (np.float64(3233.2109391932977), 67), (np.float64(3240.8437249012068), 1254)]
# ['malignant', 'malignant', 'malignant', 'benign', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2925.9748227013247), 67), (np.float64(2947.6196170988183), 986), (np.float64(2947.6196170988183), 1093), (np.float64(2987.188260589093), 957), (np.float64(3042.122681222472), 922)]
# ['benign', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3054.851664901615), 957), (np.float64(3091.9527063415644), 67), (np.float64(3144.8489411206633), 1309), (np.float64(3193.2886620396935), 75), (np.float64(3199.2501975660657), 1171)]
# ['malignant', 'benign', 'malignant', 'benign', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3100.689937022532), 67), (np.float64(3141.733502264626), 986), (np.float64(3141.733502264626), 1093), (np.float64(3159.175671683357), 957), (np.float64(3175.0824688470716), 1254)]
# ['benign', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3101.0695256615895), 67), (np.float64(3106.8585311176275), 986), (np.float64(3106.8585311176275), 1093), (np.float64(3170.219462846808), 991), (np.float64(3170.219462846808), 1095)]
# ['benign', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(2850.636136850173), 67), (np.float64(2854.835878308758), 957), (np.float64(2867.873831417743), 922), (np.float64(2892.409338591544), 983), (np.float64(2935.757055125436), 1309)]
# ['benign', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3478.0661319090127), 957), (np.float64(3586.0965135529327), 1014), (np.float64(3628.9013960315515), 991), (np.float64(3628.9013960315515), 1095), (np.float64(3631.0807575220806), 983)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3053.1779788002823), 922), (np.float64(3135.130724755387), 1008), (np.float64(3163.227499384471), 1171), (np.float64(3175.947009337838), 983), (np.float64(3195.2994358873652), 1071)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3481.6194910504537), 983), (np.float64(3484.265441213376), 1076), (np.float64(3580.475694649369), 1227), (np.float64(3590.6123003694693), 989), (np.float64(3598.934233213872), 1309)]
# ['malignant', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant
# [(np.float64(3520.62462042673), 67), (np.float64(3581.5473159083745), 955), (np.float64(3630.4450359408756), 1227), (np.float64(3653.517603494655), 957), (np.float64(3665.679460798597), 1025)]
# ['benign', 'malignant', 'malignant', 'malignant', 'malignant']
# ----------------------------------------------------------------------------------------------------
# malignant

# %%
print("recall values:")
comb_recall, comb_precision = [], []
for key in recalls.keys():
    average_val = np.average(recalls[key])
    print(key, average_val)
    comb_recall.append(average_val)
print("combined recall", np.average(comb_recall))

print("\nprecision values:")
for key in precisions.keys():
    average_val = np.average(precisions[key])
    print(key, average_val)
    comb_precision.append(average_val)
print("combined precision", np.average(comb_precision))
# Out:
# recall values:
# benign 0.05161290322580645
# malignant 0.9576642335766422
# combined recall 0.5046385684012243
#
# precision values:
# benign 0.25806451612903225
# malignant 1.0
# combined precision 0.6290322580645161
